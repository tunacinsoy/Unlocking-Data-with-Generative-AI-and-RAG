# %%
"""
   The aim of this script is to integrate a simple UI into RAG pipeline. The UI used in this script is Gradio.
   Gradio: Python library used to create user-friendly web interfaces for machine learning models, APIs, or any Python function.
"""

# Upgrade pip to latest version
# %pip install --upgrade pip

# Uninstall conflicting packages
# %pip uninstall -y langchain-core langchain-openai langchain-experimental beautifulsoup4 langchain-community langchain chromadb beautifulsoup4 gradio

    
# Install compatible versions of langchain-core and langchain-openai
# %pip install langchain-core

# Provides integration between LangChain and OpenAI’s language models
# %pip install langchain-openai

# Offers additional capabilities and tools beyond the core LangChain library that are not yet fully stable or production-ready, 
# but are still available for experimentation andexploration
# %pip install langchain-experimental

# Community-driven package for the LangChain library, which is an open source framework for building applications with LLMs
# %pip install langchain-community

# Core LangChain library itself, provides a framework and a set of abstractions for building applications with LLMs
# %pip install langchain

# High-performance embedding/vector database designed for efficient similarity search and retrieval
# %pip install chromadb

# Python library used for parsing HTML and XML documents
# %pip install beautifulsoup4

# Installing Gradio for UI functionality
# %pip install gradio

# uvloop is an event loop implementation that can improve asyncio performance. 
# However, it causes compatibility issues with other libraries (e.g., Gradio or Jupyter). 
# %pip uninstall uvloop -y

# Upgrading jupyter and ipywidgets ensures you have the latest features and bug fixes
# %pip install --upgrade jupyter ipywidgets
# Out:
# Requirement already satisfied: pip in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (24.3.1)
# Note: you may need to restart the kernel to use updated packages.
# Found existing installation: langchain-core 0.3.28
# Uninstalling langchain-core-0.3.28:
#   Successfully uninstalled langchain-core-0.3.28
# Found existing installation: langchain-openai 0.2.14
# Uninstalling langchain-openai-0.2.14:
#   Successfully uninstalled langchain-openai-0.2.14
# Found existing installation: langchain-experimental 0.3.4
# Uninstalling langchain-experimental-0.3.4:
#   Successfully uninstalled langchain-experimental-0.3.4
# Found existing installation: beautifulsoup4 4.12.3
# Uninstalling beautifulsoup4-4.12.3:
#   Successfully uninstalled beautifulsoup4-4.12.3
# Found existing installation: langchain-community 0.3.13
# Uninstalling langchain-community-0.3.13:
#   Successfully uninstalled langchain-community-0.3.13
# Found existing installation: langchain 0.3.13
# Uninstalling langchain-0.3.13:
#   Successfully uninstalled langchain-0.3.13
# Found existing installation: chromadb 0.5.23
# Uninstalling chromadb-0.5.23:
#   Successfully uninstalled chromadb-0.5.23
# Found existing installation: gradio 5.9.1
# Uninstalling gradio-5.9.1:
#   Successfully uninstalled gradio-5.9.1
# Note: you may need to restart the kernel to use updated packages.
# Collecting langchain-core
#   Using cached langchain_core-0.3.28-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: PyYAML>=5.3 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-core) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-core) (0.1.139)
# Requirement already satisfied: packaging<25,>=23.2 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-core) (24.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-core) (2.9.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-core) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.7 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-core) (4.12.2)
# Requirement already satisfied: jsonpointer>=1.9 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langsmith<0.3,>=0.1.125->langchain-core) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langsmith<0.3,>=0.1.125->langchain-core) (3.10.11)
# Requirement already satisfied: requests<3,>=2 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langsmith<0.3,>=0.1.125->langchain-core) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langsmith<0.3,>=0.1.125->langchain-core) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core) (2.23.4)
# Requirement already satisfied: anyio in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core) (4.6.2.post1)
# Requirement already satisfied: certifi in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core) (1.0.6)
# Requirement already satisfied: idna in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core) (3.10)
# Requirement already satisfied: sniffio in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from requests<3,>=2->langsmith<0.3,>=0.1.125->langchain-core) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from requests<3,>=2->langsmith<0.3,>=0.1.125->langchain-core) (2.2.3)
# Using cached langchain_core-0.3.28-py3-none-any.whl (411 kB)
# Installing collected packages: langchain-core
# Successfully installed langchain-core-0.3.28
# Note: you may need to restart the kernel to use updated packages.
# Collecting langchain-openai
#   Using cached langchain_openai-0.2.14-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.27 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-openai) (0.3.28)
# Requirement already satisfied: openai<2.0.0,>=1.58.1 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-openai) (1.58.1)
# Requirement already satisfied: tiktoken<1,>=0.7 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-openai) (0.8.0)
# Requirement already satisfied: PyYAML>=5.3 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.27->langchain-openai) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.27->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.27->langchain-openai) (0.1.139)
# Requirement already satisfied: packaging<25,>=23.2 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.27->langchain-openai) (24.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.27->langchain-openai) (2.9.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.27->langchain-openai) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.7 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.27->langchain-openai) (4.12.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (4.6.2.post1)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (0.7.0)
# Requirement already satisfied: sniffio in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (4.66.6)
# Requirement already satisfied: regex>=2022.1.18 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.9.11)
# Requirement already satisfied: requests>=2.26.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2.32.3)
# Requirement already satisfied: idna>=2.8 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.58.1->langchain-openai) (3.10)
# Requirement already satisfied: certifi in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.58.1->langchain-openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.58.1->langchain-openai) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.58.1->langchain-openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.27->langchain-openai) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain-openai) (3.10.11)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain-openai) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.27->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.27->langchain-openai) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.2.3)
# Using cached langchain_openai-0.2.14-py3-none-any.whl (50 kB)
# Installing collected packages: langchain-openai
# Successfully installed langchain-openai-0.2.14
# Note: you may need to restart the kernel to use updated packages.
# Collecting langchain-experimental
#   Using cached langchain_experimental-0.3.4-py3-none-any.whl.metadata (1.7 kB)
# Collecting langchain-community<0.4.0,>=0.3.0 (from langchain-experimental)
#   Using cached langchain_community-0.3.13-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.28 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-experimental) (0.3.28)
# Requirement already satisfied: PyYAML>=5.3 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (3.10.10)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.4.0)
# Collecting langchain<0.4.0,>=0.3.13 (from langchain-community<0.4.0,>=0.3.0->langchain-experimental)
#   Using cached langchain-0.3.13-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.1.139)
# Requirement already satisfied: numpy<2,>=1.22.4 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2.6.1)
# Requirement already satisfied: requests<3,>=2 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.28->langchain-experimental) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.28->langchain-experimental) (24.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.28->langchain-experimental) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.7 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.28->langchain-experimental) (4.12.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.17.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (3.23.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.28->langchain-experimental) (3.0.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain<0.4.0,>=0.3.13->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.3.4)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langsmith<0.3,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langsmith<0.3,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (3.10.11)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langsmith<0.3,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.28->langchain-experimental) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.28->langchain-experimental) (2.23.4)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from SQLAlchemy<3,>=1.4->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (3.1.1)
# Requirement already satisfied: anyio in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.0.6)
# Requirement already satisfied: sniffio in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.14.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.0.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.2.0)
# Using cached langchain_experimental-0.3.4-py3-none-any.whl (209 kB)
# Using cached langchain_community-0.3.13-py3-none-any.whl (2.5 MB)
# Using cached langchain-0.3.13-py3-none-any.whl (1.0 MB)
# Installing collected packages: langchain, langchain-community, langchain-experimental
# Successfully installed langchain-0.3.13 langchain-community-0.3.13 langchain-experimental-0.3.4
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: langchain-community in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (0.3.13)
# Requirement already satisfied: PyYAML>=5.3 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-community) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-community) (3.10.10)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: langchain<0.4.0,>=0.3.13 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-community) (0.3.13)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.27 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-community) (0.3.28)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-community) (0.1.139)
# Requirement already satisfied: numpy<2,>=1.22.4 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-community) (2.6.1)
# Requirement already satisfied: requests<3,>=2 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-community) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.17.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.23.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain<0.4.0,>=0.3.13->langchain-community) (0.3.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain<0.4.0,>=0.3.13->langchain-community) (2.9.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.27->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.27->langchain-community) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.27->langchain-community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langsmith<0.3,>=0.1.125->langchain-community) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langsmith<0.3,>=0.1.125->langchain-community) (3.10.11)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langsmith<0.3,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.1.1)
# Requirement already satisfied: anyio in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community) (1.0.6)
# Requirement already satisfied: sniffio in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.27->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.13->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.13->langchain-community) (2.23.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain-community) (0.2.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: langchain in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (0.3.13)
# Requirement already satisfied: PyYAML>=5.3 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain) (3.10.10)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.26 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain) (0.3.28)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain) (0.3.4)
# Requirement already satisfied: langsmith<0.3,>=0.1.17 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain) (0.1.139)
# Requirement already satisfied: numpy<2,>=1.22.4 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain) (2.9.2)
# Requirement already satisfied: requests<3,>=2 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.17.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.26->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.26->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.26->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langsmith<0.3,>=0.1.17->langchain) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langsmith<0.3,>=0.1.17->langchain) (3.10.11)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from langsmith<0.3,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: anyio in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (1.0.6)
# Requirement already satisfied: sniffio in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.26->langchain) (3.0.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain) (0.2.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting chromadb
#   Using cached chromadb-0.5.23-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: build>=1.0.3 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from chromadb) (2.9.2)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from chromadb) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from chromadb) (0.115.4)
# Requirement already satisfied: uvicorn>=0.18.3 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.32.0)
# Requirement already satisfied: numpy>=1.22.5 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from chromadb) (3.7.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from chromadb) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from chromadb) (1.20.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from chromadb) (0.48b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from chromadb) (1.27.0)
# Requirement already satisfied: tokenizers<=0.20.3,>=0.13.2 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from chromadb) (0.20.2)
# Requirement already satisfied: pypika>=0.48.9 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from chromadb) (4.66.6)
# Requirement already satisfied: overrides>=7.3.1 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from chromadb) (6.4.5)
# Requirement already satisfied: grpcio>=1.58.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from chromadb) (1.67.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from chromadb) (4.2.0)
# Requirement already satisfied: typer>=0.9.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from chromadb) (0.12.5)
# Requirement already satisfied: kubernetes>=28.1.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from chromadb) (31.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from chromadb) (8.5.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from chromadb) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from chromadb) (5.0.1)
# Requirement already satisfied: orjson>=3.9.12 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from chromadb) (3.10.11)
# Requirement already satisfied: httpx>=0.27.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from chromadb) (0.27.2)
# Requirement already satisfied: rich>=10.11.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from chromadb) (13.9.4)
# Requirement already satisfied: packaging>=19.1 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from build>=1.0.3->chromadb) (24.1)
# Requirement already satisfied: pyproject_hooks in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from fastapi>=0.95.2->chromadb) (0.41.2)
# Requirement already satisfied: anyio in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (4.6.2.post1)
# Requirement already satisfied: certifi in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (1.0.6)
# Requirement already satisfied: idna in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (3.10)
# Requirement already satisfied: sniffio in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.35.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.32.3)
# Requirement already satisfied: requests-oauthlib in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.2.3)
# Requirement already satisfied: durationpy>=0.7 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (0.9)
# Requirement already satisfied: coloredlogs in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (4.25.5)
# Requirement already satisfied: sympy in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.3)
# Requirement already satisfied: deprecated>=1.2.6 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Requirement already satisfied: importlib-metadata<=8.4.0,>=6.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.4.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.65.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.27.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-proto==1.27.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.48b0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.48b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.48b0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.48b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.48b0)
# Requirement already satisfied: opentelemetry-util-http==0.48b0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.48b0)
# ...
# Requirement already satisfied: matplotlib-inline in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack-data in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing-extensions>=4.6 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (4.12.2)
# Requirement already satisfied: pexpect>4.3 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: debugpy>=1.6.5 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from ipykernel->jupyter) (1.8.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from ipykernel->jupyter) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from ipykernel->jupyter) (5.7.2)
# Requirement already satisfied: nest-asyncio in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: packaging in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from ipykernel->jupyter) (24.1)
# Requirement already satisfied: psutil in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from ipykernel->jupyter) (6.1.0)
# Requirement already satisfied: pyzmq>=24 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from ipykernel->jupyter) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from ipykernel->jupyter) (6.4.1)
# Requirement already satisfied: async-lru>=1.0.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jupyterlab->jupyter) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jupyterlab->jupyter) (0.27.2)
# Requirement already satisfied: jinja2>=3.0.3 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jupyterlab->jupyter) (3.1.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jupyterlab->jupyter) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jupyterlab->jupyter) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jupyterlab->jupyter) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: setuptools>=40.1.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jupyterlab->jupyter) (70.3.0)
# Requirement already satisfied: beautifulsoup4 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from nbconvert->jupyter) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from nbconvert->jupyter) (6.2.0)
# Requirement already satisfied: defusedxml in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from nbconvert->jupyter) (2.1.5)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from nbconvert->jupyter) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from nbconvert->jupyter) (0.10.0)
# Requirement already satisfied: nbformat>=5.7 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from nbconvert->jupyter) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: tinycss2 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from nbconvert->jupyter) (1.4.0)
# Requirement already satisfied: webencodings in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from bleach!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: anyio in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (4.6.2.post1)
# Requirement already satisfied: certifi in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (1.0.6)
# Requirement already satisfied: idna in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (3.10)
# Requirement already satisfied: sniffio in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.3.6)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.21.0)
# Requirement already satisfied: send2trash>=1.8.2 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (4.23.0)
# Requirement already satisfied: requests>=2.31 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.32.3)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.20.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from beautifulsoup4->nbconvert->jupyter) (2.6)
# Requirement already satisfied: executing>=1.2.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: argon2-cffi-bindings in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (21.2.0)
# Requirement already satisfied: six>=1.12.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.20.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.2.3)
# Requirement already satisfied: fqdn in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: uri-template in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (24.8.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.17.1)
# Requirement already satisfied: pycparser in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.9.0.20241003)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Restart kernel after install operations are done
import IPython
app = IPython.get_ipython()
app.kernel.do_shutdown(True)
# Out:
# {'status': 'ok', 'restart': True}

# %%
# provides necesary functionalities to interact with the operating system, such as retrieving an env variable
import os

# Declaring new OS parameter to avoid warning
os.environ['USER_AGENT'] = 'RAGUserAgent'

# %%
# The WebBaseLoader class is a document loader that can fetch and load web pages as documents
from langchain_community.document_loaders import WebBaseLoader

# Beautiful Soup 4 is a library for web scraping and parsing HTML or XML documents
import bs4

# Provides an interface to interact with OpenAI’s language models and APIs
import openai

# Specific implementations of language models and embeddings that use OpenAI’s models that work directly with LangChain
from langchain_openai import ChatOpenAI, OpenAIEmbeddings

# Hub component provides access to various pre-built components and utilities for working with language models
from langchain import hub

# Parses the output generated by the language model and extracts the relevant information. 
# In this case, it assumes that the language model’s output is a string and returns it as-is.
from langchain_core.output_parsers import StrOutputParser

# This component passes through the question or query without any modifications. 
# It allows the question to be used as-is in the subsequent steps of the chain
from langchain_core.runnables import RunnablePassthrough

# Chromadb imports the Chroma DB vector store, a high-performance embedding/vector database 
# designed for efficient similarity search and retrieval.
import chromadb

# Provides an interface to interact with the Chroma vector database using LangChain
from langchain_community.vectorstores import Chroma

# A text splitter is typically a function that we use to split the text into small chunks based on a specified chunk size and overlap. 
# This splitter is called SemanticChunker, an experimental text-splitting utility provided by the Langchain_experimental library. 
# The main purpose of SemanticChunker is to break down long text into more manageable pieces 
# while preserving the semantic coherence and context of each chunk.
from langchain_experimental.text_splitter import SemanticChunker

# Introduces the concept of running the retriever and question in parallel. 
# This can improve performance by allowing the retriever to fetch the context while the question is being processed simultaneously.
from langchain_core.runnables import RunnableParallel

# Allows to define and create our own custom prompt templates
from langchain_core.prompts import PromptTemplate

# Python's standard library module for writing asynchronous programs. It allows for concurrent execution of tasks using coroutines.
import asyncio

# Modifies the asyncio event loop to allow nested event loops. 
# This is particularly useful when running asynchronous code in environments like Jupyter notebooks, where an event loop might already be running.
import nest_asyncio

# Sets the event loop policy to the default one
asyncio.set_event_loop_policy(asyncio.DefaultEventLoopPolicy())

# Modifies the event loop so that it can be reused or nested
nest_asyncio.apply()

# Imports Gradio, a library for creating interactive user interfaces for machine learning models 
import gradio as gr

# %%
# OpenAI Setup
# We will use the following API key for `gpt-4o-mini` model and
# OpenAI embedding service
openai.api_key = os.environ['OPENAI_API_KEY']

# %%
## INDEXING ##
# Next few steps represent the indexing stage, where we obtain our target data, pre-process it, and
# vectorize it. These steps are often done offline, meaning they are done to prepare the application for
# usage later. But in some cases, it may make sense to do this all in real time, such as in rapidly changing
# data environments where the data that is used is relatively small. THe overall steps are:

# 1. Web loading and crawling.
# 2. Splitting the data into digestible chunks for the Chroma DB vectorizing algorithm.
# 3. Embedding and indexing those chunks.
# 4. Adding those chunks and embeddings to the Chroma DB vector store.

# %%
# Load Documents
loader = WebBaseLoader(
    web_paths=("https://kbourne.github.io/chapter1.html",), # A tuple containing the URLs of the web pages to be loaded.
    bs_kwargs=dict( # A dictionary of keyword arguments to be passed to the BeautifulSoup parser.
        parse_only=bs4.SoupStrainer( # specifies the HTML elements to parse. In this case, it is set to parse only the elements with the CSS classes
            class_=("post-content", "post-title", "post-header")
        )
    ),
)
docs = loader.load()

# I. Makes HTTP requests to the specified URLs to fetch the web pages.
# II. Parses the HTML content of the web pages using BeautifulSoup, considering only the elements specified by
# the parse_only parameter.
# III. Extracts the relevant text content from the parsed HTML elements.
# IV. Creates Document objects for each web page that contain the extracted text content, along with metadata such as the source URL.

# %%
# Splitting
# SemanticChunker focuses on breaking down long text into more manageable pieces while preserving
# the semantic coherence and context of each chunk.
# There are other text splitters that are not context-aware, and does the splitting by arbitrarily
# defined sizes, but SemanticChunker focuses on accounting for context 
# rather than just arbitrary length of our chunks

embeddings = OpenAIEmbeddings(
    model="text-embedding-3-small",
    # With the `text-embedding-3` class
    # of models, you can specify the size
    # of the embeddings you want returned.
    # dimensions=1024
)

text_splitter = SemanticChunker(embeddings)
splits = text_splitter.split_documents(docs)

# %%
# Embed
# We are using OpenAI embeddings here as well as well splitting step, 
# which will use our OpenAI key to send our chunks of data to the OpenAI API, convert them into embeddings, 
# and then send them back in their mathematical form.

# First, we create the Chroma vector store with the Chroma.from_documents method, which is called to
# create a Chroma vector store from the documents that we used split operation before
vectorstore = Chroma.from_documents(
    documents=splits, # The list of split documents (splits) obtained from the previous code snippet 
    embedding=embeddings # An instance of the OpenAIEmbeddings class, which is used to generate embeddings for the documents
)

# What happens under the hood is:
# 1. It iterates over each Document object in the splits list.
# 2. For each Document object, it uses the provided OpenAIEmbeddings instance to generate an embedding vector.
# 3. It stores the document text and its corresponding embedding vector in the Chroma vector database.


# The retriever is an object that provides a convenient interface for performing similarity searches 
# and retrieving the relevant documents from the vector database based on those searches
retriever = vectorstore.as_retriever()

# %%
#### RETRIEVAL and GENERATION ####

# Here's what we will do in the following steps:
# 1. Take in a user query.
# 2. Vectorize that user query.
# 3. Perform a similarity search of the vector store to find the closest vectors to the user query vector, as well as their associated
# content.
# 4. Pass the retrieved content into a prompt template, a process known as hydrating.
# 5. Pass that hydrated prompt to the LLM.
# 6. Once you receive a response from the LLM, present it to the user.

# %%
# Prompt - ignore LangSmith warning, you will not need langsmith for this coding exercise
prompt = hub.pull("jclemens24/rag-prompt")

# The prompt template is a key part of the RAG pipeline as it represents how you communicate with the
# LLM to receive the response you are seeking
# Out:
# /home/tuna/.local/share/mise/installs/python/3.11.10/lib/python3.11/site-packages/langsmith/client.py:234: LangSmithMissingAPIKeyWarning: API key must be provided when using hosted LangSmith API
#   warnings.warn(

# %%
# Relevance check prompt
relevance_prompt_template = PromptTemplate.from_template(
    """
    Given the following question and retrieved context, determine if the context is relevant to the question.
    Provide a score from 1 to 5, where 1 is not at all relevant and 5 is highly relevant.
    Return ONLY the numeric score, without any additional text or explanation.

    Question: {question}
    Retrieved Context: {retrieved_context}

    Relevance Score:"""
)

# %%
# Post-processing

# The join method is called on the \n\n string to concatenate page_content of each document with two
# newline characters between each document’s content.

# The purpose of this function is to format the output of the retriever into the string format that it will 
# need to be in for the next step in the chain, after the retriever step.
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

# %%
# Function will receive the output of llm, which will be the relevancy of the question 
# with the given context from 1 to 5. Then, it will parse it is as float, and will return a float.
def extract_score(llm_relevance_score) -> float:
    try:
        score = float(llm_relevance_score.strip())
        return score
    except ValueError:
        return 0.0  # Returning 0.0 as a float instead of an integer

# %%
# This function will accept the response of llm, and returns the answer based on
# the relevance score.
# We are to determine the relevancy of the question as a security measure to block prompt injections
def conditional_answer(llm_response) -> str:
    relevance_score = extract_score(llm_response["relevance_score"])
    if relevance_score < 4:
        return "I do not know."
    else:
        return llm_response["answer"]

# %%
# LLM
# Creates an instance of the ChatOpenAI class from the langchain_openai module,
# which serves as an interface to OpenAI’s language models
llm = ChatOpenAI(model_name="gpt-4o-mini", temperature=0)


# The temperature parameter in Large Language Models (LLMs) 
# directly affects the variability and randomness of generated responses. 
# A lower LLM temperature value (close to 0) produces more deterministic and focused outputs, 
# ideal for tasks requiring factual accuracy, such as summarization or translation.

# %%
# We are defining RunnablePassthrough for concurrency, because we need two different outputs from LLM:
# Relevance Score: LLM will check if the question that is asked by the user is relative to the context provided.s
# Answer: LLM will give answer based on the context it receives.

rag_chain_from_docs = (
    RunnablePassthrough.assign(context=(lambda x: format_docs(x["context"])))
    | RunnableParallel(
        {"relevance_score": (
            RunnablePassthrough()
            | (lambda x: relevance_prompt_template.format(question=x['question'], retrieved_context=x['context']))
            | llm
            | StrOutputParser()
        ), "answer": (
            RunnablePassthrough()
            | prompt
            | llm
            | StrOutputParser()
        )}
    )
    | RunnablePassthrough().assign(final_answer=conditional_answer)
)

# %%
rag_chain_with_source = RunnableParallel(
    {"context": retriever, "question": RunnablePassthrough()}
).assign(answer=rag_chain_from_docs)

# %%
# Gradio Interface

# Function to be run once submit button is pressed on Gradio UI
def process_question(question):
    result = rag_chain_with_source.invoke(question)

    # # "result" is a dictionary, and within that, the "answer" key is also a dictionary
    relevance_score = result['answer']['relevance_score']
    final_answer = result['answer']['final_answer']
    
    sources = [doc.metadata['source'] for doc in result['context']]
    source_list = ", ".join(sources)
    
    # We return three values, and each of them will be mapped to output fields defined in gr.Interface() function
    return relevance_score, final_answer, source_list

demo = gr.Interface(
    # Function to be called 
    fn=process_question,
    # Input field configuration (for user query)
    inputs=gr.Textbox(label="Enter your question", value="What are the advantages of using RAG?"),
    # Output fields configuration, each output will be retrieved from process_question function
    outputs=[
        gr.Textbox(label="Relevance Score"),
        gr.Textbox(label="Final Answer"),
        gr.Textbox(label="Sources")
    ],
    title="RAG Question Answering",
    description="Enter a question and get the relevance score, final answer, and sources from RAG."
)

# %%
# debug = True -> enables verbose logging during the app's execution
# share = True -> creates sharable public URL
# After launch, press square icon to stop hosting
# For the jupyter notebook to show the UI, first delete the output if it already exists, and then run the cell again
demo.launch(share = True, debug = True)

# For enabling simple authentication
# demo.launch(share = True, debug = True, auth=("tuna","tuna1234")
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://f0fc1e4a52e7d25786.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://f0fc1e4a52e7d25786.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
