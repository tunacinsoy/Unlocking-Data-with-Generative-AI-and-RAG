# %%
# %pip install --upgrade pip

# Uninstall conflicting packages
# %pip uninstall -y langchain-core langchain-openai langchain-experimental beautifulsoup4 langchain-community langchain chromadb beautifulsoup4

# Install compatible versions of langchain-core and langchain-openai
# %pip install langchain-core==0.3.6
# %pip install langchain-openai==0.2.1
# %pip install langchain-experimental==0.3.2
# %pip install langchain-community==0.3.1
# %pip install langchain==0.3.1

# Install remaining packages
# %pip install chromadb==0.5.11
# %pip install beautifulsoup4==4.12.3

# Restart the kernel after installation
# Out:
# Requirement already satisfied: pip in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (24.3.1)
# Note: you may need to restart the kernel to use updated packages.
# Found existing installation: langchain-core 0.3.15
# Uninstalling langchain-core-0.3.15:
#   Successfully uninstalled langchain-core-0.3.15
# Found existing installation: langchain-openai 0.2.1
# Uninstalling langchain-openai-0.2.1:
#   Successfully uninstalled langchain-openai-0.2.1
# Found existing installation: langchain-experimental 0.3.2
# Uninstalling langchain-experimental-0.3.2:
#   Successfully uninstalled langchain-experimental-0.3.2
# Found existing installation: beautifulsoup4 4.12.3
# Uninstalling beautifulsoup4-4.12.3:
#   Successfully uninstalled beautifulsoup4-4.12.3
# Found existing installation: langchain-community 0.3.1
# Uninstalling langchain-community-0.3.1:
#   Successfully uninstalled langchain-community-0.3.1
# Found existing installation: langchain 0.3.1
# Uninstalling langchain-0.3.1:
#   Successfully uninstalled langchain-0.3.1
# WARNING: Skipping chromadb as it is not installed.
# Note: you may need to restart the kernel to use updated packages.
# Collecting langchain-core==0.3.6
#   Using cached langchain_core-0.3.6-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: PyYAML>=5.3 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-core==0.3.6) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-core==0.3.6) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-core==0.3.6) (0.1.139)
# Requirement already satisfied: packaging<25,>=23.2 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-core==0.3.6) (24.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-core==0.3.6) (2.9.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-core==0.3.6) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.7 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-core==0.3.6) (4.12.2)
# Requirement already satisfied: jsonpointer>=1.9 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core==0.3.6) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core==0.3.6) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core==0.3.6) (3.10.11)
# Requirement already satisfied: requests<3,>=2 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core==0.3.6) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core==0.3.6) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core==0.3.6) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core==0.3.6) (2.23.4)
# Requirement already satisfied: anyio in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core==0.3.6) (4.6.2.post1)
# Requirement already satisfied: certifi in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core==0.3.6) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core==0.3.6) (1.0.6)
# Requirement already satisfied: idna in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core==0.3.6) (3.10)
# Requirement already satisfied: sniffio in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core==0.3.6) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core==0.3.6) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.125->langchain-core==0.3.6) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.125->langchain-core==0.3.6) (2.2.3)
# Using cached langchain_core-0.3.6-py3-none-any.whl (399 kB)
# Installing collected packages: langchain-core
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-text-splitters 0.3.2 requires langchain-core<0.4.0,>=0.3.15, but you have langchain-core 0.3.6 which is incompatible.
# Successfully installed langchain-core-0.3.6
# Note: you may need to restart the kernel to use updated packages.
# Collecting langchain-openai==0.2.1
#   Using cached langchain_openai-0.2.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: langchain-core<0.4,>=0.3 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-openai==0.2.1) (0.3.6)
# Requirement already satisfied: openai<2.0.0,>=1.40.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-openai==0.2.1) (1.53.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-openai==0.2.1) (0.8.0)
# Requirement already satisfied: PyYAML>=5.3 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-core<0.4,>=0.3->langchain-openai==0.2.1) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-core<0.4,>=0.3->langchain-openai==0.2.1) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-core<0.4,>=0.3->langchain-openai==0.2.1) (0.1.139)
# Requirement already satisfied: packaging<25,>=23.2 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-core<0.4,>=0.3->langchain-openai==0.2.1) (24.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-core<0.4,>=0.3->langchain-openai==0.2.1) (2.9.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-core<0.4,>=0.3->langchain-openai==0.2.1) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.7 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-core<0.4,>=0.3->langchain-openai==0.2.1) (4.12.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.2.1) (4.6.2.post1)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.2.1) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.2.1) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.2.1) (0.7.0)
# Requirement already satisfied: sniffio in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.2.1) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.2.1) (4.66.6)
# Requirement already satisfied: regex>=2022.1.18 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from tiktoken<1,>=0.7->langchain-openai==0.2.1) (2024.9.11)
# Requirement already satisfied: requests>=2.26.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from tiktoken<1,>=0.7->langchain-openai==0.2.1) (2.32.3)
# Requirement already satisfied: idna>=2.8 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.40.0->langchain-openai==0.2.1) (3.10)
# Requirement already satisfied: certifi in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain-openai==0.2.1) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain-openai==0.2.1) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain-openai==0.2.1) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3->langchain-openai==0.2.1) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3->langchain-openai==0.2.1) (3.10.11)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3->langchain-openai==0.2.1) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4,>=0.3->langchain-openai==0.2.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4,>=0.3->langchain-openai==0.2.1) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai==0.2.1) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai==0.2.1) (2.2.3)
# Using cached langchain_openai-0.2.1-py3-none-any.whl (49 kB)
# Installing collected packages: langchain-openai
# Successfully installed langchain-openai-0.2.1
# Note: you may need to restart the kernel to use updated packages.
# Collecting langchain-experimental==0.3.2
#   Using cached langchain_experimental-0.3.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting langchain-community<0.4.0,>=0.3.0 (from langchain-experimental==0.3.2)
#   Using cached langchain_community-0.3.5-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.6 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-experimental==0.3.2) (0.3.6)
# Requirement already satisfied: PyYAML>=5.3 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.2) (6.0.2)
# Requirement already satisfied: SQLAlchemy<2.0.36,>=1.4 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.2) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.2) (3.10.10)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.2) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.2) (0.4.0)
# Collecting langchain<0.4.0,>=0.3.6 (from langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.2)
#   Using cached langchain-0.3.7-py3-none-any.whl.metadata (7.1 kB)
# Collecting langchain-core<0.4.0,>=0.3.6 (from langchain-experimental==0.3.2)
#   Using cached langchain_core-0.3.15-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.2) (0.1.139)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.2) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.2) (2.6.1)
# Requirement already satisfied: requests<3,>=2 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.2) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.2) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.6->langchain-experimental==0.3.2) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.6->langchain-experimental==0.3.2) (24.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.6->langchain-experimental==0.3.2) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.7 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.6->langchain-experimental==0.3.2) (4.12.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.2) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.2) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.2) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.2) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.2) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.2) (1.17.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.2) (3.23.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.2) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.6->langchain-experimental==0.3.2) (3.0.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain<0.4.0,>=0.3.6->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.2) (0.3.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.2) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.2) (3.10.11)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.2) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4.0,>=0.3.6->langchain-experimental==0.3.2) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4.0,>=0.3.6->langchain-experimental==0.3.2) (2.23.4)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.2) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.2) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.2) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.2) (2024.8.30)
# Requirement already satisfied: anyio in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.2) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.2) (1.0.6)
# Requirement already satisfied: sniffio in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.2) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.2) (0.14.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.2) (1.0.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental==0.3.2) (0.2.0)
# Using cached langchain_experimental-0.3.2-py3-none-any.whl (208 kB)
# Using cached langchain_community-0.3.5-py3-none-any.whl (2.4 MB)
# Using cached langchain_core-0.3.15-py3-none-any.whl (408 kB)
# Using cached langchain-0.3.7-py3-none-any.whl (1.0 MB)
# Installing collected packages: langchain-core, langchain, langchain-community, langchain-experimental
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.6
#     Uninstalling langchain-core-0.3.6:
#       Successfully uninstalled langchain-core-0.3.6
# Successfully installed langchain-0.3.7 langchain-community-0.3.5 langchain-core-0.3.15 langchain-experimental-0.3.2
# Note: you may need to restart the kernel to use updated packages.
# Collecting langchain-community==0.3.1
#   Using cached langchain_community-0.3.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: PyYAML>=5.3 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-community==0.3.1) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-community==0.3.1) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-community==0.3.1) (3.10.10)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-community==0.3.1) (0.6.7)
# Requirement already satisfied: langchain<0.4.0,>=0.3.1 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-community==0.3.1) (0.3.7)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.6 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-community==0.3.1) (0.3.15)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-community==0.3.1) (0.1.139)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-community==0.3.1) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-community==0.3.1) (2.6.1)
# Requirement already satisfied: requests<3,>=2 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-community==0.3.1) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-community==0.3.1) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.1) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.1) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.1) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.1) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.1) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.1) (1.17.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.1) (3.23.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.1) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain<0.4.0,>=0.3.1->langchain-community==0.3.1) (0.3.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain<0.4.0,>=0.3.1->langchain-community==0.3.1) (2.9.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.6->langchain-community==0.3.1) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.6->langchain-community==0.3.1) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.6->langchain-community==0.3.1) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-community==0.3.1) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-community==0.3.1) (3.10.11)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-community==0.3.1) (1.0.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community==0.3.1) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from requests<3,>=2->langchain-community==0.3.1) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from requests<3,>=2->langchain-community==0.3.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from requests<3,>=2->langchain-community==0.3.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from requests<3,>=2->langchain-community==0.3.1) (2024.8.30)
# Requirement already satisfied: anyio in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community==0.3.1) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community==0.3.1) (1.0.6)
# Requirement already satisfied: sniffio in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community==0.3.1) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community==0.3.1) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.6->langchain-community==0.3.1) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.1->langchain-community==0.3.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.1->langchain-community==0.3.1) (2.23.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.1) (1.0.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.1) (0.2.0)
# Using cached langchain_community-0.3.1-py3-none-any.whl (2.4 MB)
# Installing collected packages: langchain-community
#   Attempting uninstall: langchain-community
#     Found existing installation: langchain-community 0.3.5
#     Uninstalling langchain-community-0.3.5:
#       Successfully uninstalled langchain-community-0.3.5
# Successfully installed langchain-community-0.3.1
# Note: you may need to restart the kernel to use updated packages.
# Collecting langchain==0.3.1
#   Using cached langchain-0.3.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: PyYAML>=5.3 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain==0.3.1) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain==0.3.1) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain==0.3.1) (3.10.10)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.6 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain==0.3.1) (0.3.15)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain==0.3.1) (0.3.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain==0.3.1) (0.1.139)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain==0.3.1) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain==0.3.1) (2.9.2)
# Requirement already satisfied: requests<3,>=2 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain==0.3.1) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain==0.3.1) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.1) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.1) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.1) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.1) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.1) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.1) (1.17.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.6->langchain==0.3.1) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.6->langchain==0.3.1) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.6->langchain==0.3.1) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.3.1) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.3.1) (3.10.11)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.3.1) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.1) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from requests<3,>=2->langchain==0.3.1) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from requests<3,>=2->langchain==0.3.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from requests<3,>=2->langchain==0.3.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from requests<3,>=2->langchain==0.3.1) (2024.8.30)
# Requirement already satisfied: anyio in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.3.1) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.3.1) (1.0.6)
# Requirement already satisfied: sniffio in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.3.1) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.3.1) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.6->langchain==0.3.1) (3.0.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain==0.3.1) (0.2.0)
# Using cached langchain-0.3.1-py3-none-any.whl (1.0 MB)
# Installing collected packages: langchain
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.7
#     Uninstalling langchain-0.3.7:
#       Successfully uninstalled langchain-0.3.7
# Successfully installed langchain-0.3.1
# Note: you may need to restart the kernel to use updated packages.
# Collecting chromadb
#   Using cached chromadb-0.5.17-py3-none-any.whl.metadata (6.8 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Using cached build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pydantic>=1.9 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from chromadb) (2.9.2)
# Collecting chroma-hnswlib==0.7.6 (from chromadb)
#   Using cached chroma_hnswlib-0.7.6.tar.gz (32 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting fastapi>=0.95.2 (from chromadb)
#   Using cached fastapi-0.115.4-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached uvicorn-0.32.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy>=1.22.5 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from chromadb) (1.26.4)
# Collecting posthog>=2.4.0 (from chromadb)
#   Using cached posthog-3.7.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from chromadb) (4.12.2)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Using cached onnxruntime-1.20.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.4 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Using cached opentelemetry_api-1.27.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.27.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb)
#   Using cached opentelemetry_instrumentation_fastapi-0.48b0-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Using cached opentelemetry_sdk-1.27.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting tokenizers>=0.13.2 (from chromadb)
#   Using cached tokenizers-0.20.2-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting pypika>=0.48.9 (from chromadb)
#   Using cached PyPika-0.48.9-py2.py3-none-any.whl
# Requirement already satisfied: tqdm>=4.65.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from chromadb) (4.66.6)
# Requirement already satisfied: overrides>=7.3.1 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from chromadb) (7.7.0)
# Collecting importlib-resources (from chromadb)
#   Using cached importlib_resources-6.4.5-py3-none-any.whl.metadata (4.0 kB)
# Collecting grpcio>=1.58.0 (from chromadb)
#   Using cached grpcio-1.67.1-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Using cached bcrypt-4.2.0-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (9.6 kB)
# Collecting typer>=0.9.0 (from chromadb)
#   Using cached typer-0.12.5-py3-none-any.whl.metadata (15 kB)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Using cached kubernetes-31.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from chromadb) (8.5.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from chromadb) (6.0.2)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Using cached mmh3-5.0.1-cp313-cp313-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: orjson>=3.9.12 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from chromadb) (3.10.11)
# Requirement already satisfied: httpx>=0.27.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from chromadb) (0.27.2)
# Collecting rich>=10.11.0 (from chromadb)
#   Using cached rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: packaging>=19.1 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from build>=1.0.3->chromadb) (24.1)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Using cached pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting starlette<0.42.0,>=0.40.0 (from fastapi>=0.95.2->chromadb)
#   Using cached starlette-0.41.2-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: anyio in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from httpx>=0.27.0->chromadb) (4.6.2.post1)
# Requirement already satisfied: certifi in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from httpx>=0.27.0->chromadb) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from httpx>=0.27.0->chromadb) (1.0.6)
# Requirement already satisfied: idna in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from httpx>=0.27.0->chromadb) (3.10)
# Requirement already satisfied: sniffio in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Collecting google-auth>=1.0.1 (from kubernetes>=28.1.0->chromadb)
#   Using cached google_auth-2.35.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (2.32.3)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting oauthlib>=3.2.2 (from kubernetes>=28.1.0->chromadb)
#   Using cached oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: urllib3>=1.24.2 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (2.2.3)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Using cached durationpy-0.9-py3-none-any.whl.metadata (338 bytes)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb)
#   Using cached flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting protobuf (from onnxruntime>=1.14.1->chromadb)
#   Using cached protobuf-5.28.3-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting sympy (from onnxruntime>=1.14.1->chromadb)
#   Using cached sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.2.0->chromadb)
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting importlib-metadata<=8.4.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb)
#   Using cached importlib_metadata-8.4.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting googleapis-common-protos~=1.52 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached googleapis_common_protos-1.65.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.27.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached opentelemetry_exporter_otlp_proto_common-1.27.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.27.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached opentelemetry_proto-1.27.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting protobuf (from onnxruntime>=1.14.1->chromadb)
#   Using cached protobuf-4.25.5-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Collecting opentelemetry-instrumentation-asgi==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached opentelemetry_instrumentation_asgi-0.48b0-py3-none-any.whl.metadata (2.0 kB)
# Collecting opentelemetry-instrumentation==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached opentelemetry_instrumentation-0.48b0-py3-none-any.whl.metadata (6.1 kB)
# Collecting opentelemetry-semantic-conventions==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
# ...
#             |                                       ^
#       ./python_bindings/bindings.cpp:960:38: note: in instantiation of member function 'Index<float>::createFromParams' requested here
#         960 |         .def(py::init(&Index<float>::createFromParams), py::arg("params"))
#             |                                      ^
#       ./python_bindings/bindings.cpp:736:40: warning: cannot delete expression with pointer-to-'void' type 'void *' [-Wdelete-incomplete]
#         736 |                                      { delete[] f; });
#             |                                        ^        ~
#       ./python_bindings/bindings.cpp:736:38: note: while substituting into a lambda expression here
#         736 |                                      { delete[] f; });
#             |                                      ^
#       ./python_bindings/bindings.cpp:974:29: note: in instantiation of member function 'Index<float>::knnQuery_return_numpy' requested here
#         974 |              &Index<float>::knnQuery_return_numpy,
#             |                             ^
#       ./python_bindings/bindings.cpp:738:40: warning: cannot delete expression with pointer-to-'void' type 'void *' [-Wdelete-incomplete]
#         738 |                                      { delete[] f; });
#             |                                        ^        ~
#       ./python_bindings/bindings.cpp:738:38: note: while substituting into a lambda expression here
#         738 |                                      { delete[] f; });
#             |                                      ^
#       ./python_bindings/bindings.cpp:974:29: note: in instantiation of member function 'Index<float>::knnQuery_return_numpy' requested here
#         974 |              &Index<float>::knnQuery_return_numpy,
#             |                             ^
#       ./python_bindings/bindings.cpp:684:22: warning: comparison of integers of different signs: 'size_t' (aka 'unsigned long') and 'int' [-Wsign-compare]
#         684 |             if (rows <= num_threads * 4)
#             |                 ~~~~ ^  ~~~~~~~~~~~~~~~
#       ./python_bindings/bindings.cpp:974:29: note: in instantiation of member function 'Index<float>::knnQuery_return_numpy' requested here
#         974 |              &Index<float>::knnQuery_return_numpy,
#             |                             ^
#       ./python_bindings/bindings.cpp:310:22: warning: comparison of integers of different signs: 'size_t' (aka 'unsigned long') and 'int' [-Wsign-compare]
#         310 |         if (features != dim)
#             |             ~~~~~~~~ ^  ~~~
#       ./python_bindings/bindings.cpp:980:29: note: in instantiation of member function 'Index<float>::addItems' requested here
#         980 |              &Index<float>::addItems,
#             |                             ^
#       ./python_bindings/bindings.cpp:314:18: warning: comparison of integers of different signs: 'size_t' (aka 'unsigned long') and 'int' [-Wsign-compare]
#         314 |         if (rows <= num_threads * 4)
#             |             ~~~~ ^  ~~~~~~~~~~~~~~~
#       In file included from ./python_bindings/bindings.cpp:6:
#       In file included from ./hnswlib/hnswlib.h:221:
#       ./hnswlib/hnswalg.h:1208:31: warning: comparison of integers of different signs: 'int' and 'size_t' (aka 'unsigned long') [-Wsign-compare]
#        1208 |             for (int i = 0; i < dim; i++)
#             |                             ~ ^ ~~~
#       ./python_bindings/bindings.cpp:367:47: note: in instantiation of function template specialization 'hnswlib::HierarchicalNSW<float>::getDataByLabel<float>' requested here
#         367 |             data.push_back(appr_alg->template getDataByLabel<data_t>(id));
#             |                                               ^
#       ./python_bindings/bindings.cpp:985:49: note: in instantiation of member function 'Index<float>::getDataReturnList' requested here
#         985 |         .def("get_items", &Index<float, float>::getDataReturnList, py::arg("ids") = py::none())
#             |                                                 ^
#       ./python_bindings/bindings.cpp:432:41: warning: cannot delete expression with pointer-to-'void' type 'void *' [-Wdelete-incomplete]
#         432 |                                       { delete[] f; });
#             |                                         ^        ~
#       ./python_bindings/bindings.cpp:432:39: note: while substituting into a lambda expression here
#         432 |                                       { delete[] f; });
#             |                                       ^
#       ./python_bindings/bindings.cpp:511:27: note: in instantiation of member function 'Index<float>::getAnnData' requested here
#         511 |         auto ann_params = getAnnData();
#             |                           ^
#       ./python_bindings/bindings.cpp:1025:39: note: in instantiation of member function 'Index<float>::getIndexParams' requested here
#        1025 |             return py::make_tuple(ind.getIndexParams()); /* Return dict (wrapped in a tuple) that fully encodes state of the Index object */
#             |                                       ^
#       ./python_bindings/bindings.cpp:434:42: warning: cannot delete expression with pointer-to-'void' type 'void *' [-Wdelete-incomplete]
#         434 |                                        { delete[] f; });
#             |                                          ^        ~
#       ./python_bindings/bindings.cpp:434:40: note: while substituting into a lambda expression here
#         434 |                                        { delete[] f; });
#             |                                        ^
#       ./python_bindings/bindings.cpp:511:27: note: in instantiation of member function 'Index<float>::getAnnData' requested here
#         511 |         auto ann_params = getAnnData();
#             |                           ^
#       ./python_bindings/bindings.cpp:1025:39: note: in instantiation of member function 'Index<float>::getIndexParams' requested here
#        1025 |             return py::make_tuple(ind.getIndexParams()); /* Return dict (wrapped in a tuple) that fully encodes state of the Index object */
#             |                                       ^
#       ./python_bindings/bindings.cpp:436:41: warning: cannot delete expression with pointer-to-'void' type 'void *' [-Wdelete-incomplete]
#         436 |                                       { delete[] f; });
#             |                                         ^        ~
#       ./python_bindings/bindings.cpp:436:39: note: while substituting into a lambda expression here
#         436 |                                       { delete[] f; });
#             |                                       ^
#       ./python_bindings/bindings.cpp:511:27: note: in instantiation of member function 'Index<float>::getAnnData' requested here
#         511 |         auto ann_params = getAnnData();
#             |                           ^
#       ./python_bindings/bindings.cpp:1025:39: note: in instantiation of member function 'Index<float>::getIndexParams' requested here
#        1025 |             return py::make_tuple(ind.getIndexParams()); /* Return dict (wrapped in a tuple) that fully encodes state of the Index object */
#             |                                       ^
#       ./python_bindings/bindings.cpp:438:41: warning: cannot delete expression with pointer-to-'void' type 'void *' [-Wdelete-incomplete]
#         438 |                                       { delete[] f; });
#             |                                         ^        ~
#       ./python_bindings/bindings.cpp:438:39: note: while substituting into a lambda expression here
#         438 |                                       { delete[] f; });
#             |                                       ^
#       ./python_bindings/bindings.cpp:511:27: note: in instantiation of member function 'Index<float>::getAnnData' requested here
#         511 |         auto ann_params = getAnnData();
#             |                           ^
#       ./python_bindings/bindings.cpp:1025:39: note: in instantiation of member function 'Index<float>::getIndexParams' requested here
#        1025 |             return py::make_tuple(ind.getIndexParams()); /* Return dict (wrapped in a tuple) that fully encodes state of the Index object */
#             |                                       ^
#       ./python_bindings/bindings.cpp:440:41: warning: cannot delete expression with pointer-to-'void' type 'void *' [-Wdelete-incomplete]
#         440 |                                       { delete[] f; });
#             |                                         ^        ~
#       ./python_bindings/bindings.cpp:440:39: note: while substituting into a lambda expression here
#         440 |                                       { delete[] f; });
#             |                                       ^
#       ./python_bindings/bindings.cpp:511:27: note: in instantiation of member function 'Index<float>::getAnnData' requested here
#         511 |         auto ann_params = getAnnData();
#             |                           ^
#       ./python_bindings/bindings.cpp:1025:39: note: in instantiation of member function 'Index<float>::getIndexParams' requested here
#        1025 |             return py::make_tuple(ind.getIndexParams()); /* Return dict (wrapped in a tuple) that fully encodes state of the Index object */
#             |                                       ^
#       In file included from ./python_bindings/bindings.cpp:6:
#       In file included from ./hnswlib/hnswlib.h:220:
#       ./hnswlib/bruteforce.h:112:31: warning: comparison of integers of different signs: 'int' and 'size_t' (aka 'unsigned long') [-Wsign-compare]
#         112 |             for (int i = 0; i < k; i++)
#             |                             ~ ^ ~
#       ./hnswlib/bruteforce.h:60:9: note: in instantiation of member function 'hnswlib::BruteforceSearch<float>::searchKnn' requested here
#          60 |         ~BruteforceSearch()
#             |         ^
#       ./python_bindings/bindings.cpp:823:13: note: in instantiation of member function 'hnswlib::BruteforceSearch<float>::~BruteforceSearch' requested here
#         823 |             delete alg;
#             |             ^
#       /usr/bin/../lib/gcc/x86_64-linux-gnu/13/../../../../include/c++/13/bits/unique_ptr.h:99:2: note: in instantiation of member function 'BFIndex<float>::~BFIndex' requested here
#          99 |         delete __ptr;
#             |         ^
#       /usr/bin/../lib/gcc/x86_64-linux-gnu/13/../../../../include/c++/13/bits/unique_ptr.h:404:4: note: in instantiation of member function 'std::default_delete<BFIndex<float>>::operator()' requested here
#         404 |           get_deleter()(std::move(__ptr));
#             |           ^
#       /tmp/pip-build-env-6z5res1k/overlay/lib/python3.13/site-packages/pybind11/include/pybind11/pybind11.h:1926:40: note: in instantiation of member function 'std::unique_ptr<BFIndex<float>>::~unique_ptr' requested here
#        1926 |             v_h.holder<holder_type>().~holder_type();
#             |                                        ^
#       /tmp/pip-build-env-6z5res1k/overlay/lib/python3.13/site-packages/pybind11/include/pybind11/pybind11.h:1585:26: note: in instantiation of member function 'pybind11::class_<BFIndex<float>>::dealloc' requested here
#        1585 |         record.dealloc = dealloc;
#             |                          ^
#       ./python_bindings/bindings.cpp:1036:5: note: in instantiation of function template specialization 'pybind11::class_<BFIndex<float>>::class_<>' requested here
#        1036 |     py::class_<BFIndex<float>>(m, "BFIndex")
#             |     ^
#       In file included from ./python_bindings/bindings.cpp:6:
#       In file included from ./hnswlib/hnswlib.h:220:
#       ./hnswlib/bruteforce.h:122:31: warning: comparison of integers of different signs: 'int' and 'const size_t' (aka 'const unsigned long') [-Wsign-compare]
#         122 |             for (int i = k; i < cur_element_count; i++)
#             |                             ~ ^ ~~~~~~~~~~~~~~~~~
#       ./python_bindings/bindings.cpp:936:40: warning: cannot delete expression with pointer-to-'void' type 'void *' [-Wdelete-incomplete]
#         936 |                                      { delete[] f; });
#             |                                        ^        ~
#       ./python_bindings/bindings.cpp:936:38: note: while substituting into a lambda expression here
#         936 |                                      { delete[] f; });
#             |                                      ^
#       ./python_bindings/bindings.cpp:1039:44: note: in instantiation of member function 'BFIndex<float>::knnQuery_return_numpy' requested here
#        1039 |         .def("knn_query", &BFIndex<float>::knnQuery_return_numpy, py::arg("data"), py::arg("k") = 1, py::arg("filter") = py::none())
#             |                                            ^
#       ./python_bindings/bindings.cpp:938:40: warning: cannot delete expression with pointer-to-'void' type 'void *' [-Wdelete-incomplete]
#         938 |                                      { delete[] f; });
#             |                                        ^        ~
#       ./python_bindings/bindings.cpp:938:38: note: while substituting into a lambda expression here
#         938 |                                      { delete[] f; });
#             |                                      ^
#       ./python_bindings/bindings.cpp:1039:44: note: in instantiation of member function 'BFIndex<float>::knnQuery_return_numpy' requested here
#        1039 |         .def("knn_query", &BFIndex<float>::knnQuery_return_numpy, py::arg("data"), py::arg("k") = 1, py::arg("filter") = py::none())
#             |                                            ^
#       ./python_bindings/bindings.cpp:854:22: warning: comparison of integers of different signs: 'size_t' (aka 'unsigned long') and 'int' [-Wsign-compare]
#         854 |         if (features != dim)
#             |             ~~~~~~~~ ^  ~~~
#       ./python_bindings/bindings.cpp:1040:44: note: in instantiation of member function 'BFIndex<float>::addItems' requested here
#        1040 |         .def("add_items", &BFIndex<float>::addItems, py::arg("data"), py::arg("ids") = py::none())
#             |                                            ^
#       In file included from ./python_bindings/bindings.cpp:6:
#       ./hnswlib/hnswlib.h:87:13: warning: unused function 'AVX512Capable' [-Wunused-function]
#          87 | static bool AVX512Capable()
#             |             ^~~~~~~~~~~~~
#       38 warnings generated.
#       creating build/lib.linux-x86_64-cpython-313
#       clang++ -pthread -fno-strict-overflow -Wsign-compare -Wunreachable-code -DNDEBUG -g -O3 -Wall -fPIC -pthread -shared -Wl,--exclude-libs,ALL -LModules/_hacl build/temp.linux-x86_64-cpython-313/./python_bindings/bindings.o -L/install/lib -o build/lib.linux-x86_64-cpython-313/hnswlib.cpython-313-x86_64-linux-gnu.so -fopenmp -pthread
#       /usr/bin/ld: cannot find -lomp: No such file or directory
#       clang++: error: linker command failed with exit code 1 (use -v to see invocation)
#       error: command '/usr/bin/clang++' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for chroma-hnswlib
# Failed to build chroma-hnswlib
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (chroma-hnswlib)
# Note: you may need to restart the kernel to use updated packages.
# Collecting beautifulsoup4==4.12.3
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: soupsieve>1.2 in /home/tuna/.local/share/mise/installs/python/latest/lib/python3.13/site-packages (from beautifulsoup4==4.12.3) (2.6)
# Using cached beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Installing collected packages: beautifulsoup4
# Successfully installed beautifulsoup4-4.12.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# New OS parameter to avoid warnings.  
# This will not have a material impact on your code, but prevents warnings from appearing related to new LangChain features.
import os
os.environ['USER_AGENT'] = 'RAGUserAgent'

# %%
from langchain_community.document_loaders import WebBaseLoader
import bs4
import openai
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain import hub
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
import chromadb
from langchain_community.vectorstores import Chroma
from langchain_experimental.text_splitter import SemanticChunker
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 8
#       6 from langchain_core.output_parsers import StrOutputParser
#       7 from langchain_core.runnables import RunnablePassthrough
# ----> 8 import chromadb
#       9 from langchain_community.vectorstores import Chroma
#      10 from langchain_experimental.text_splitter import SemanticChunker
#
# ModuleNotFoundError: No module named 'chromadb'

# %%
# OpenAI Setup
os.environ['OPENAI_API_KEY'] = ''
openai.api_key = os.environ['OPENAI_API_KEY']

# %%
#### INDEXING ####

# %%
# Load Documents
loader = WebBaseLoader(
    web_paths=("https://kbourne.github.io/chapter1.html",), 
    bs_kwargs=dict(
        parse_only=bs4.SoupStrainer(
            class_=("post-content", "post-title", "post-header")
        )
    ),
)
docs = loader.load()

# %%
# Split
text_splitter = SemanticChunker(OpenAIEmbeddings())
splits = text_splitter.split_documents(docs)

# %%
# Embed
vectorstore = Chroma.from_documents(documents=splits, 
                                    embedding=OpenAIEmbeddings())

retriever = vectorstore.as_retriever()

# %%
#### RETRIEVAL and GENERATION ####

# %%
# Prompt - ignore LangSmith warning, you will not need langsmith for this coding exercise
prompt = hub.pull("jclemens24/rag-prompt")

# %%
# Post-processing
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

# %%
# LLM
llm = ChatOpe33nAI(model_name="gpt-4o-mini", temperature=0)

# %%
# Chain it all together with LangChain
rag_chain = (
    {"context": retriever | format_docs, "question": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

# %%
# Question - run the chain
rag_chain.invoke("What are the advantages of using RAG?")
